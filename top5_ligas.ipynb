# %% [markdown]
# #limpieza de datos

# %%
import pandas as pd
import numpy as np

# %%
stats_players = pd.read_csv('/content/sample_data/top5-players.csv')

# %%
stats_players.head(10)
# Out:
#    Rk             Player   Nation    Pos           Squad                Comp  \
# 0   1         Max Aarons  eng ENG     DF     Bournemouth  eng Premier League
# 1   2   Brenden Aaronson   us USA  MF,FW    Union Berlin       de Bundesliga
# 2   3    Paxten Aaronson   us USA     MF  Eint Frankfurt       de Bundesliga
# 3   4  Keyliane Abdallah   fr FRA     FW       Marseille          fr Ligue 1
# 4   5   Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
# 5   6  Salis Abdul Samed   gh GHA     MF            Lens          fr Ligue 1
# 6   7      Nabil Aberdin   fr FRA     DF          Getafe          es La Liga
# 7   8    Laurent Abergel   fr FRA     MF         Lorient          fr Ligue 1
# 8   9     Matthis Abline   fr FRA     FW          Nantes          fr Ligue 1
# 9  10              Abner   br BRA     DF           Betis          es La Liga
#
#     Age    Born  MP  Starts  ...  Gls_90  Ast_90  G+A_90  G-PK_90  G+A-PK_90  \
# ...

# %%
stats_players.describe()
# Out:
#                 Rk          Age         Born           MP       Starts  \
# count  2852.000000  2848.000000  2848.000000  2852.000000  2852.000000
# mean   1426.500000    25.060744  1997.600070    18.969846    13.514727
# std     823.445809     4.590521     4.596294    11.517930    11.251227
# min       1.000000    15.000000  1982.000000     1.000000     0.000000
# 25%     713.750000    22.000000  1994.000000     8.000000     2.000000
# 50%    1426.500000    25.000000  1998.000000    20.000000    12.000000
# 75%    2139.250000    28.000000  2001.000000    29.000000    23.000000
# max    2852.000000    40.000000  2008.000000    38.000000    38.000000
#
#                Min          90s          Gls          Ast          G+A  ...  \
# count  2852.000000  2852.000000  2852.000000  2852.000000  2852.000000  ...
# mean   1213.301543    13.482328     1.720196     1.221950     2.942146  ...
# std     961.584066    10.685045     3.203532     1.965371     4.615768  ...
# ...

# %% [markdown]
# #verificar valores nulos

# %%
stats_players.isnull().sum()
# Out:
# Rk             0
# Player         0
# Nation         3
# Pos            0
# Squad          0
# Comp           0
# Age            4
# Born           4
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             1
# npxG           1
# xAG            1
# npxG+xAG       1
# PrgC           1
# PrgP           1
# PrgR           1
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          1
# xAG_90         1
# xG+xAG_90      1
# npxG_90        1
# npxG+xAG_90    1
# dtype: int64

# %%
#borrar todos los dtos nulos
stats_players.dropna(inplace=True)

# %%
stats_players.isnull().sum()
# Out:
# Rk             0
# Player         0
# Nation         0
# Pos            0
# Squad          0
# Comp           0
# Age            0
# Born           0
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             0
# npxG           0
# xAG            0
# npxG+xAG       0
# PrgC           0
# PrgP           0
# PrgR           0
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          0
# xAG_90         0
# xG+xAG_90      0
# npxG_90        0
# npxG+xAG_90    0
# dtype: int64

# %% [markdown]
# #guardar nuevo archivo con datos limpios

# %%
stats_players.to_excel('stats_players_clean.xlsx')

# %%
stats_players_clean = pd.read_excel('/content/stats_players_clean.xlsx')

# %%
stats_players_clean.tail()
# Out:
#       Unnamed: 0    Rk            Player  Nation    Pos          Squad  \
# 2841        2847  2848    Lovro Zvonarek  hr CRO  FW,MF  Bayern Munich
# 2842        2848  2849   Martin Ødegaard  no NOR     MF        Arsenal
# 2843        2849  2850       Milan Đurić  ba BIH     FW  Hellas Verona
# 2844        2850  2851       Milan Đurić  ba BIH     FW          Monza
# 2845        2851  2852  Mateusz Łęgowski  pl POL     MF    Salernitana
#
#                     Comp  Age  Born  MP  ...  Gls_90  Ast_90  G+A_90  G-PK_90  \
# 2841       de Bundesliga   18  2005   5  ...    0.55    0.00    0.55     0.55
# 2842  eng Premier League   24  1998  35  ...    0.23    0.29    0.52     0.17
# 2843          it Serie A   33  1990  20  ...    0.37    0.07    0.45     0.30
# 2844          it Serie A   33  1990  17  ...    0.29    0.07    0.36     0.29
# 2845          it Serie A   20  2003  29  ...    0.00    0.00    0.00     0.00
#
#       G+A-PK_90  xG_90  xAG_90  xG+xAG_90  npxG_90  npxG+xAG_90
# ...

# %%
#estadisticas descriptivas
stats_players_clean.describe()
# Out:
#         Unnamed: 0           Rk          Age         Born           MP  \
# count  2846.000000  2846.000000  2846.000000  2846.000000  2846.000000
# mean   1424.466268  1425.466268    25.065706  1997.594870    19.004568
# std     823.836421   823.836421     4.588237     4.593641    11.504151
# min       0.000000     1.000000    15.000000  1982.000000     1.000000
# 25%     711.250000   712.250000    22.000000  1994.000000     8.000000
# 50%    1423.500000  1424.500000    25.000000  1998.000000    20.000000
# 75%    2138.750000  2139.750000    28.000000  2001.000000    29.000000
# max    2851.000000  2852.000000    40.000000  2008.000000    38.000000
#
#             Starts          Min          90s          Gls          Ast  ...  \
# count  2846.000000  2846.000000  2846.000000  2846.000000  2846.000000  ...
# mean     13.541110  1215.606817    13.507941     1.723823     1.224526  ...
# std      11.248069   961.243136    10.681251     3.205933     1.966640  ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.histplot(stats_players_clean['Gls_90'])
# Out:
# <Axes: xlabel='Gls_90', ylabel='Count'>

# %%
sns.scatterplot(data=stats_players_clean, x='Gls_90', y='Age')
# Out:
# <Axes: xlabel='Gls_90', ylabel='Age'>

# %%
sns.scatterplot(data=stats_players_clean, x='xG_90', y='Gls_90')
# Out:
# <Axes: xlabel='xG_90', ylabel='Gls_90'>
